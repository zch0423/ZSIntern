# %%
import sys
sys.path.append("..")
from roeProcessTools import *
# import roeProcessTools as tl
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from datetime import datetime
# import scipy.signal as signal
# from random import sample

# %%
temp = pd.read_excel("data/chemRoeClean.xlsx")

# %%
tl.showOne("00", temp)

# %%
a = np.array([5,4,3,2,1,0,1,2,3,4,3,2,-1])

# %%
signal.argrelextrema(a, np.less_equal, order=4)
# Out:
# (array([ 5, 12]),)

# %%
signal.argrelmin(a, order=4)
# Out:
# (array([5]),)

# %%
signal.argrelmax(a, order=4)
# Out:
# (array([9]),)

# %%
signal.argrelextrema(-a, np.greater_equal, order=4)[0]
# Out:
# array([ 5, 12])
