# %%
import sys
sys.path.append("..")

# %%
import usefulFuncs as uf

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import scipy.signal as signal
from random import sample
from scipy.stats.mstats import winsorize

# %%
roePath = "/Users/zch/Desktop/internship/Jan14/机械roeData.xlsx"

# %%
roe = pd.read_excel(roePath)

# %%
goodCodes, temp = uf.selectCompanyByAbsDiff(roe,  absDiff=1.7, threshold=0.3, order=3, minNum=40, minExtreme=4, winsorize=True)

# %%
# temp.to_excel("temp39GoodROE.xlsx", index=False)
len(goodCodes)
# Out:
# 39

# %%
tt = temp[temp["code"].apply(lambda x:x in goodCodes)]

# %%
tt.to_excel("temp39GoodROE.xlsx", index=False)

# %%
marked = uf.markCompanies(tt)
# Out:
# code    002595.SZ
# name         豪迈科技
# Name: 60, dtype: object

# %%
marked.to_excel("roeMarked.xlsx", index=False)

# %%
uf.showOne("002595", tt)

# %%
diffPath = "/Users/zch/Desktop/internship/Jan18/temp58Good.xlsx"
diff = pd.read_excel(diffPath)

# %%
allDiffPath = "/Users/zch/Desktop/internship/Jan15/machineROEDiff.xlsx"
allDiff = pd.read_excel(allDiffPath)

# %%
uf.showOne("002595", allDiff)

# %%
# 000039
# 000528
uf.showOne("000039", tt)
uf.showOne("000039", diff)

# %%
uf.showOne("000528", tt)
uf.showOne("000528", diff)

# %%
uf.showOne("002480.SZ", tt)
uf.showOne("002480.SZ", allDiff)
