# %% [markdown]
# ## test for facebook/prophet

# %%
import pandas as pd
from fbprophet import Prophet

# %%
path = "/Users/zch/Desktop/internship/data/chemClean32.xlsx"
df = pd.read_excel(path)

# %%
code = "000731"
# Out:
#           code  name  2000-12  2001-03  ...   2019-12  2020-03  2020-06  2020-09
# 0    000059.SZ  华锦股份      NaN      NaN  ...   0.51030  -5.0940  1.72490  3.91070
# 1    000096.SZ  广聚能源      NaN      NaN  ...   0.72150   0.0677  0.94640  3.36800
# 2    000159.SZ  国际实业      NaN      NaN  ...   1.92160  -1.2682  4.31010 -0.13450
# 3    000301.SZ  东方盛虹      NaN      NaN  ...   3.09490   1.3506 -0.20786  0.99600
# 4    000420.SZ  吉林化纤      NaN      NaN  ...   0.30480   0.5129 -3.25480 -4.49260
# ..         ...   ...      ...      ...  ...       ...      ...      ...      ...
# 180  603077.SH  和邦生物      NaN      NaN  ...   0.46310  -0.2791  0.68150 -0.54012
# 181  603299.SH  苏盐井神      NaN      NaN  ...   0.67290   1.8918  1.86990  0.27970
# 182  900908.SH  氯碱B股      NaN      NaN  ...   3.98150   1.8769  1.23850  4.00810
# 183  900909.SH  华谊B股      NaN      NaN  ...   0.46530  -1.1032  0.61810  0.76750
# 184  900921.SH  丹科B股      NaN      NaN  ... -11.02128  -3.3590 -4.65090 -5.94600
#
# [185 rows x 82 columns]
