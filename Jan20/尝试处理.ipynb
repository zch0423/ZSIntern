# %%
import sys
sys.path.append("..")
from roeProcessTools import *

# %%
dirPath = "/Users/zch/Desktop/internship/data/"
paths = {"chem":"化工roe.xlsx", "mach":"机械设备roe.xlsx", "food":"食品饮料roe.xlsx", "elec":"电子roe.xlsx"}

# %%
# for industry, filePath in paths.items():
#     df = pd.read_excel(dirPath+filePath)
#     # df = clean(df, startYear=2000, endYear=2021, minNum=32, winsorizeBool=True)
#     df = clean(df, startYear=2000, endYear=2021, minNum=40, winsorizeBool=True)
#     df.to_excel(f"{dirPath}{industry}Clean.xlsx", index=False)
#     df = greaterThanStd(df, n=8, gaussian=True, center=True)
#     df.to_excel(f"{dirPath}{industry}GreaterThanStd.xlsx", index=False)
#     # df = selectGood(df, n=1.5, minExtreme=4, proportion=0.2)
#     df = selectGood(df, n=2, minExtreme=4, proportion=0.2)
#     print(industry, "共筛选出%d个公司"%len(df))
#     df.to_excel(f"{dirPath}{industry}Selected.xlsx", index=False)
#     marked = markCompanies(df)
#     marked.to_excel(f"{dirPath}{industry}Marked.xlsx", index=False)

# %%
roes = {}
markeds = {}
for industry in paths.keys():
    roePath = f"{dirPath}{industry}Selected.xlsx"
    roes[industry] = pd.read_excel(roePath)
    mPath  = f"{dirPath}{industry}Marked.xlsx"
    markeds[industry] = pd.read_excel(mPath)

# %%
industry = "chem"
print(industry)
for code in roes[industry].code.values:
    showOne(code, roes[industry], markeds[industry])
# Out:
# chem
