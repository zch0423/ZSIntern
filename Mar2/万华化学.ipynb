# %%
import sys
sys.path.append("..")
from roeProcessTools import *

# %%
filePath = "/Users/zch/Desktop/internship/SWROEData/cleanData/SW化工.xlsx"

# %%
df = pd.read_excel(filePath)

# %%
df.head()
# Out:
#         code  name  2000-12  2001-03  2001-06  2001-09  2001-12  2002-03  \
# 0  000059.SZ  华锦股份      NaN      NaN      NaN   0.2600  -0.1924   0.2154
# 1  000096.SZ  广聚能源      NaN      NaN      NaN      NaN      NaN   1.9954
# 2  000159.SZ  国际实业      NaN      NaN      NaN   0.9284   3.0246   0.2253
# 3  000301.SZ  东方盛虹      NaN      NaN      NaN   1.8798   2.0269   1.4324
# 4  000420.SZ  吉林化纤      NaN      NaN      NaN      NaN      NaN   0.2867
#
#    2002-06  2002-09  ...  2018-09  2018-12  2019-03  2019-06  2019-09  \
# 0   0.5451 -0.58250  ...  2.26990  -0.0284   2.5835  1.43870   2.8470
# 1   2.2516  1.97330  ...  0.63060   0.4704   0.4159  1.00920   2.7707
# 2   0.2197 -1.57466  ...  3.16780   1.5499   1.0988 -0.56680  -1.0599
# 3   2.0077  1.52400  ... -0.20786   1.5276   2.4191  3.12772   2.9561
# 4   1.2641  0.03650  ...  1.70320   0.1512   0.6440  1.75080   0.3671
#
#    2019-12  2020-03  2020-06  2020-09  2020-12
# 0   0.5103  -5.0940  1.72490   3.9107      NaN
# ...

# %%
showOne("002080", df)

# %%
showOne("600309", df)

# %%
# from cfProcessTools import *

# %%
cfFile = "/Users/zch/Desktop/internship/SWCFData/clean/化工.xlsx"

# %%
df1 = pd.read_excel(cfFile)

# %%
showOne("600309", df1)
